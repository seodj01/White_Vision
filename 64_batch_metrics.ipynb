# %% [markdown]
# ## 배치 사이즈 64로 학습 Case

# %%
import pandas as pd

data=pd.read_csv("./metrics_csv/64_batch_metrics.csv")
data
# Out:
#        epoch  phase  batch_loss  batch_iou  pixel_acc  iou_Sidewalk  \
# 0          1  train    2.215477   0.032683   0.068393           NaN
# 1          1  train    2.240354   0.022073   0.045983           NaN
# 2          1  train    2.216433   0.026330   0.057060           NaN
# 3          1  train    2.189175   0.024189   0.059370           NaN
# 4          1  train    2.171731   0.035188   0.079365           NaN
# ...      ...    ...         ...        ...        ...           ...
# 18781     23    val    0.699224   0.513328   0.718566      0.666389
# 18782     23    val    0.356567   0.510930   0.753512      0.715063
# 18783     23    val    0.524951   0.528627   0.745610      0.691139
# 18784     23    val    0.351492   0.452853   0.755420      0.729795
# 18785     23    val    0.467559   0.368748   0.758474      0.707595
#
#        iou_Braille Guide Blocks  iou_Roadway  iou_Alley  iou_Bike Lane  \
# 0                           NaN          NaN        NaN            NaN
# 1                           NaN          NaN        NaN            NaN
# 2                           NaN          NaN        NaN            NaN
# 3                           NaN          NaN        NaN            NaN
# 4                           NaN          NaN        NaN            NaN
# ...                         ...          ...        ...            ...
# 18781                  0.619139     0.209188   0.671974       0.266082
# 18782                  0.622192     0.315039   0.769840       0.235071
# 18783                  0.573537     0.079716   0.771479       0.269202
# 18784                  0.531515     0.160927   0.801406       0.249187
# 18785                  0.416087     0.066882   0.734328       0.234672
#
#        iou_Caution Zone  iou_Cross walk
# 0                   NaN             NaN
# 1                   NaN             NaN
# 2                   NaN             NaN
# 3                   NaN             NaN
# 4                   NaN             NaN
# ...                 ...             ...
# 18781          0.638625        0.521902
# 18782          0.782156        0.137148
# 18783          0.821468        0.493846
# 18784          0.284568        0.412573
# 18785          0.000000        0.421670
#
# [18786 rows x 12 columns]

# %% [markdown]
# ### 훈련 데이터

# %%
filtered_data=data[(data['phase']=="train") & (data['epoch']<=12)]
filtered_data
# Out:
#       epoch  phase  batch_loss  batch_iou  pixel_acc  iou_Sidewalk  \
# 0         1  train    2.215477   0.032683   0.068393           NaN
# 1         1  train    2.240354   0.022073   0.045983           NaN
# 2         1  train    2.216433   0.026330   0.057060           NaN
# 3         1  train    2.189175   0.024189   0.059370           NaN
# 4         1  train    2.171731   0.035188   0.079365           NaN
# ...     ...    ...         ...        ...        ...           ...
# 9205     12  train    0.133648   0.593377   0.789670           NaN
# 9206     12  train    0.184686   0.567708   0.772481           NaN
# 9207     12  train    0.157533   0.569506   0.777528           NaN
# 9208     12  train    0.167090   0.520807   0.774267           NaN
# 9209     12  train    0.146984   0.480704   0.803293           NaN
#
#       iou_Braille Guide Blocks  iou_Roadway  iou_Alley  iou_Bike Lane  \
# 0                          NaN          NaN        NaN            NaN
# 1                          NaN          NaN        NaN            NaN
# 2                          NaN          NaN        NaN            NaN
# 3                          NaN          NaN        NaN            NaN
# 4                          NaN          NaN        NaN            NaN
# ...                        ...          ...        ...            ...
# 9205                       NaN          NaN        NaN            NaN
# 9206                       NaN          NaN        NaN            NaN
# 9207                       NaN          NaN        NaN            NaN
# 9208                       NaN          NaN        NaN            NaN
# 9209                       NaN          NaN        NaN            NaN
#
#       iou_Caution Zone  iou_Cross walk
# 0                  NaN             NaN
# 1                  NaN             NaN
# 2                  NaN             NaN
# 3                  NaN             NaN
# 4                  NaN             NaN
# ...                ...             ...
# 9205               NaN             NaN
# 9206               NaN             NaN
# 9207               NaN             NaN
# 9208               NaN             NaN
# 9209               NaN             NaN
#
# [7692 rows x 12 columns]

# %%
filtered_data[['epoch','batch_loss','batch_iou','pixel_acc']]
# Out:
#       epoch  batch_loss  batch_iou  pixel_acc
# 0         1    2.215477   0.032683   0.068393
# 1         1    2.240354   0.022073   0.045983
# 2         1    2.216433   0.026330   0.057060
# 3         1    2.189175   0.024189   0.059370
# 4         1    2.171731   0.035188   0.079365
# ...     ...         ...        ...        ...
# 9205     12    0.133648   0.593377   0.789670
# 9206     12    0.184686   0.567708   0.772481
# 9207     12    0.157533   0.569506   0.777528
# 9208     12    0.167090   0.520807   0.774267
# 9209     12    0.146984   0.480704   0.803293
#
# [7692 rows x 4 columns]

# %% [markdown]
# ### 훈련 데이터 loss

# %%
import matplotlib.pyplot as plt

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# 선 그래프 그리기
plt.plot(filtered_data['batch_loss'], 
         color='blue', linestyle='-', linewidth=2, markersize=5, label='Loss')

# 축 레이블과 제목 설정
plt.xlabel('Step', fontsize=12, labelpad=10)
plt.ylabel('Loss', fontsize=12, labelpad=10)
plt.title('Train Loss(batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()

# %% [markdown]
# ### 훈련 데이터 iou

# %%
import matplotlib.pyplot as plt

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# 선 그래프 그리기
plt.plot(filtered_data['batch_iou'], 
         color='blue', linestyle='-', linewidth=2, markersize=5, label='Iou')

# 축 레이블과 제목 설정
plt.xlabel('Step', fontsize=12, labelpad=10)
plt.ylabel('IoU', fontsize=12, labelpad=10)
plt.title('Train IoU(batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()

# %% [markdown]
# ### 훈련 데이터 pixel_acc

# %%
import matplotlib.pyplot as plt

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# 선 그래프 그리기
plt.plot(filtered_data['pixel_acc'], 
         color='blue', linestyle='-', linewidth=2, markersize=5, label='pixel_acc')

# 축 레이블과 제목 설정
plt.xlabel('Step', fontsize=12, labelpad=10)
plt.ylabel('pixel_acc', fontsize=12, labelpad=10)
plt.title('Train pixel_accuracy(batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()

# %% [markdown]
# ### 검증 데이터

# %%
filtered_data2=data[(data['phase']=="val") & (data['epoch']<=12)]
filtered_data2
# Out:
#       epoch phase  batch_loss  batch_iou  pixel_acc  iou_Sidewalk  \
# 588       1   val    0.511755   0.357458   0.725113      0.758981
# 589       1   val    0.595463   0.388914   0.749509      0.717130
# 590       1   val    0.661096   0.390175   0.690694      0.641615
# 591       1   val    0.522405   0.422385   0.755943      0.797633
# 592       1   val    0.532331   0.401144   0.725994      0.713746
# ...     ...   ...         ...        ...        ...           ...
# 9343     12   val    0.579228   0.508133   0.720169      0.669362
# 9344     12   val    0.311051   0.500109   0.755313      0.723065
# 9345     12   val    0.430403   0.509388   0.745003      0.707609
# 9346     12   val    0.284828   0.424830   0.749206      0.731155
# 9347     12   val    0.423205   0.375182   0.756516      0.693032
#
#       iou_Braille Guide Blocks  iou_Roadway  iou_Alley  iou_Bike Lane  \
# 588                   0.033418     0.222097   0.793298       0.171974
# 589                   0.223014     0.276528   0.754113       0.127215
# 590                   0.184289     0.384712   0.703137       0.200598
# 591                   0.167666     0.237223   0.764223       0.124022
# 592                   0.139818     0.273639   0.811122       0.140076
# ...                        ...          ...        ...            ...
# 9343                  0.539003     0.250527   0.685370       0.231155
# 9344                  0.482809     0.352034   0.784435       0.199513
# 9345                  0.486104     0.070321   0.775863       0.253518
# 9346                  0.260579     0.181150   0.779760       0.230515
# 9347                  0.335384     0.191569   0.746630       0.218443
#
#       iou_Caution Zone  iou_Cross walk
# 588           0.491665        0.030774
# 589           0.603663        0.020735
# 590           0.596533        0.020341
# 591           0.641727        0.224203
# 592           0.704207        0.025399
# ...                ...             ...
# 9343          0.654102        0.527410
# 9344          0.775822        0.183087
# 9345          0.789504        0.482798
# 9346          0.343779        0.446876
# 9347          0.000000        0.441219
#
# [1656 rows x 12 columns]

# %% [markdown]
# ### loss 그래프

# %%
import matplotlib.pyplot as plt

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# 선 그래프 그리기
plt.plot(filtered_data2['batch_loss'], 
         color='red', linestyle='-', linewidth=2, markersize=5, label='loss')

# 축 레이블과 제목 설정
plt.xlabel('Step', fontsize=12, labelpad=10)
plt.ylabel('Loss', fontsize=12, labelpad=10)
plt.title('Validation Loss(batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()

# %% [markdown]
# ### IoU 그래프

# %%
import matplotlib.pyplot as plt

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# 선 그래프 그리기
plt.plot(filtered_data2['batch_iou'], 
         color='red', linestyle='-', linewidth=2, markersize=5, label='IoU')

# 축 레이블과 제목 설정
plt.xlabel('Step', fontsize=12, labelpad=10)
plt.ylabel('IoU', fontsize=12, labelpad=10)
plt.title('Validation IoU(batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()

# %% [markdown]
# ### Pixel_acc

# %%
import matplotlib.pyplot as plt

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# 선 그래프 그리기
plt.plot(filtered_data2['pixel_acc'], 
         color='red', linestyle='-', linewidth=2, markersize=5, label='pixel_acc')

# 축 레이블과 제목 설정
plt.xlabel('Step', fontsize=12, labelpad=10)
plt.ylabel('pixel_acc', fontsize=12, labelpad=10)
plt.title('Validation pixel_acc(batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()

# %% [markdown]
# ### epoch 별 csv

# %%
new_data=pd.read_csv('./metrics_csv/64_epoch_metrics.csv')
new_data
# Out:
#     epoch  phase  epoch_loss  epoch_iou  pixel_acc  iou_Sidewalk  \
# 0       1  train    0.914849   0.288810   0.634381      0.000000
# 1       1    val    0.621031   0.363839   0.717052      0.712704
# 2       2  train    0.527973   0.383836   0.706207      0.000000
# 3       2    val    0.473274   0.411076   0.735570      0.725297
# 4       3  train    0.432179   0.415328   0.718487      0.000000
# 5       3    val    0.405747   0.434118   0.744520      0.730534
# 6       4  train    0.377559   0.432837   0.726882      0.000000
# 7       4    val    0.380510   0.452125   0.747534      0.733302
# 8       5  train    0.338922   0.452520   0.734343      0.000000
# 9       5    val    0.358771   0.463900   0.751125      0.731805
# 10      6  train    0.309304   0.466125   0.740182      0.000000
# 11      6    val    0.347350   0.477263   0.752568      0.729563
# 12      7  train    0.282143   0.482824   0.746485      0.000000
# 13      7    val    0.341594   0.480995   0.753970      0.730471
# 14      8  train    0.257271   0.494898   0.752927      0.000000
# 15      8    val    0.348553   0.487367   0.753377      0.720003
# 16      9  train    0.234429   0.510172   0.759128      0.000000
# 17      9    val    0.355233   0.489988   0.752365      0.716383
# 18     10  train    0.213307   0.525200   0.764874      0.000000
# 19     10    val    0.357355   0.493629   0.753915      0.723760
# 20     11  train    0.193077   0.538555   0.770892      0.000000
# 21     11    val    0.365191   0.497589   0.754736      0.724096
# 22     12  train    0.177713   0.551169   0.774867      0.000000
# 23     12    val    0.375609   0.501575   0.753872      0.717382
# 24     13  train    0.161257   0.564507   0.779577      0.000000
# 25     13    val    0.381615   0.501676   0.753379      0.719013
# 26     14  train    0.149857   0.571929   0.782659      0.000000
# 27     14    val    0.394411   0.508799   0.752569      0.709686
# 28     15  train    0.138927   0.583184   0.785579      0.000000
# 29     15    val    0.399308   0.505648   0.752793      0.714983
# 30     14  train    0.150556   0.572815   0.782466      0.000000
# 31     14    val    0.390709   0.505837   0.753757      0.718285
# 32     15  train    0.138735   0.584132   0.785666      0.000000
# 33     15    val    0.398730   0.508859   0.752434      0.714518
# 34     16  train    0.129476   0.590608   0.788037      0.000000
# 35     16    val    0.408238   0.511114   0.753417      0.717098
# 36     17  train    0.121088   0.598634   0.790305      0.000000
# 37     17    val    0.425945   0.509543   0.751267      0.717580
# 38     18  train    0.114834   0.604096   0.791804      0.000000
# 39     18    val    0.425410   0.512544   0.752745      0.714289
# 40     19  train    0.107352   0.610837   0.793750      0.000000
# 41     19    val    0.428570   0.515279   0.753548      0.712834
# 42     20  train    0.102895   0.615984   0.794863      0.000000
# 43     20    val    0.446685   0.511172   0.752184      0.720457
# 44     21  train    0.097415   0.617611   0.796235      0.000000
# 45     21    val    0.447191   0.516083   0.753378      0.717424
# 46     22  train    0.093717   0.624833   0.797211      0.000000
# 47     22    val    0.462443   0.513023   0.752110      0.715049
# 48     23  train    0.088926   0.627472   0.798353      0.000000
# 49     23    val    0.456215   0.517060   0.754107      0.710608
#
#     iou_Braille Guide Blocks  iou_Roadway  iou_Alley  iou_Bike Lane  \
# 0                   0.000000     0.000000   0.000000       0.000000
# 1                   0.139200     0.202369   0.734883       0.134009
# 2                   0.000000     0.000000   0.000000       0.000000
# 3                   0.172983     0.255888   0.749649       0.170814
# 4                   0.000000     0.000000   0.000000       0.000000
# 5                   0.225731     0.269978   0.753429       0.185316
# 6                   0.000000     0.000000   0.000000       0.000000
# 7                   0.273695     0.276847   0.753733       0.187451
# 8                   0.000000     0.000000   0.000000       0.000000
# 9                   0.308361     0.289173   0.761466       0.190133
# 10                  0.000000     0.000000   0.000000       0.000000
# 11                  0.369312     0.287622   0.757155       0.202040
# 12                  0.000000     0.000000   0.000000       0.000000
# 13                  0.385356     0.280790   0.761100       0.207186
# 14                  0.000000     0.000000   0.000000       0.000000
# 15                  0.413534     0.292377   0.764637       0.218689
# 16                  0.000000     0.000000   0.000000       0.000000
# 17                  0.430129     0.300802   0.761332       0.218636
# 18                  0.000000     0.000000   0.000000       0.000000
# 19                  0.462871     0.287311   0.761054       0.226971
# 20                  0.000000     0.000000   0.000000       0.000000
# 21                  0.482911     0.277428   0.761804       0.224240
# 22                  0.000000     0.000000   0.000000       0.000000
# 23                  0.494814     0.288873   0.764870       0.225059
# 24                  0.000000     0.000000   0.000000       0.000000
# 25                  0.520308     0.277108   0.753563       0.237255
# 26                  0.000000     0.000000   0.000000       0.000000
# 27                  0.537253     0.296250   0.757175       0.252455
# 28                  0.000000     0.000000   0.000000       0.000000
# 29                  0.549393     0.273554   0.756762       0.243663
# 30                  0.000000     0.000000   0.000000       0.000000
# 31                  0.535721     0.286889   0.755515       0.237853
# 32                  0.000000     0.000000   0.000000       0.000000
# 33                  0.553874     0.278533   0.755623       0.243816
# 34                  0.000000     0.000000   0.000000       0.000000
# 35                  0.567169     0.281664   0.758603       0.240041
# 36                  0.000000     0.000000   0.000000       0.000000
# 37                  0.575117     0.280935   0.744036       0.240704
# 38                  0.000000     0.000000   0.000000       0.000000
# 39                  0.579496     0.283441   0.753974       0.242404
# 40                  0.000000     0.000000   0.000000       0.000000
# 41                  0.583995     0.293008   0.752905       0.248091
# 42                  0.000000     0.000000   0.000000       0.000000
# 43                  0.592586     0.268901   0.752222       0.243191
# 44                  0.000000     0.000000   0.000000       0.000000
# 45                  0.599035     0.284752   0.755740       0.240160
# 46                  0.000000     0.000000   0.000000       0.000000
# 47                  0.601076     0.279402   0.753490       0.241078
# 48                  0.000000     0.000000   0.000000       0.000000
# 49                  0.592613     0.285132   0.755622       0.251448
#
#     iou_Caution Zone  iou_Cross walk
# 0           0.000000        0.000000
# 1           0.475450        0.148259
# 2           0.000000        0.000000
# 3           0.541604        0.261298
# 4           0.000000        0.000000
# 5           0.560951        0.312887
# 6           0.000000        0.000000
# 7           0.590145        0.349703
# 8           0.000000        0.000000
# 9           0.599720        0.366644
# 10          0.000000        0.000000
# 11          0.607803        0.387345
# 12          0.000000        0.000000
# 13          0.599598        0.402463
# 14          0.000000        0.000000
# 15          0.608803        0.393526
# 16          0.000000        0.000000
# 17          0.606578        0.396056
# 18          0.000000        0.000000
# 19          0.604053        0.389382
# 20          0.000000        0.000000
# 21          0.605548        0.407096
# 22          0.000000        0.000000
# 23          0.611609        0.408422
# 24          0.000000        0.000000
# 25          0.609365        0.395123
# 26          0.000000        0.000000
# 27          0.613537        0.395240
# 28          0.000000        0.000000
# 29          0.606498        0.394686
# 30          0.000000        0.000000
# 31          0.607102        0.399490
# 32          0.000000        0.000000
# 33          0.614325        0.401327
# 34          0.000000        0.000000
# 35          0.616424        0.396800
# 36          0.000000        0.000000
# 37          0.610758        0.397669
# 38          0.000000        0.000000
# 39          0.616149        0.398055
# 40          0.000000        0.000000
# 41          0.617120        0.399003
# 42          0.000000        0.000000
# 43          0.611395        0.389454
# 44          0.000000        0.000000
# 45          0.612605        0.402863
# 46          0.000000        0.000000
# 47          0.611412        0.389654
# 48          0.000000        0.000000
# 49          0.620390        0.403608

# %% [markdown]
# ### 훈련 데이터

# %%
new=new_data[(new_data['phase']=="train") & (new_data['epoch']<=12)]
new=new[['epoch','epoch_loss','epoch_iou','pixel_acc']]
new
# Out:
#     epoch  epoch_loss  epoch_iou  pixel_acc
# 0       1    0.914849   0.288810   0.634381
# 2       2    0.527973   0.383836   0.706207
# 4       3    0.432179   0.415328   0.718487
# 6       4    0.377559   0.432837   0.726882
# 8       5    0.338922   0.452520   0.734343
# 10      6    0.309304   0.466125   0.740182
# 12      7    0.282143   0.482824   0.746485
# 14      8    0.257271   0.494898   0.752927
# 16      9    0.234429   0.510172   0.759128
# 18     10    0.213307   0.525200   0.764874
# 20     11    0.193077   0.538555   0.770892
# 22     12    0.177713   0.551169   0.774867

# %% [markdown]
# ### loss 그래프

# %%
import matplotlib.pyplot as plt

# x축 데이터 추출
epochs = new['epoch']
epoch_loss = new['epoch_loss']

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# 선 그래프 그리기
plt.plot(epochs, epoch_loss, 
         color='blue', linestyle='-', linewidth=2, label='Loss')

# 축 레이블과 제목 설정
plt.xlabel('Epoch', fontsize=12, labelpad=10)
plt.ylabel('Loss', fontsize=12, labelpad=10)
plt.title('Train Loss (batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()

# %% [markdown]
# ### iou 그래프

# %%
import matplotlib.pyplot as plt

# x축 데이터 추출
epochs = new['epoch']
epoch_iou = new['epoch_iou']

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# 선 그래프 그리기
plt.plot(epochs, epoch_iou, 
         color='blue', linestyle='-', linewidth=2, label='IoU')

# 축 레이블과 제목 설정
plt.xlabel('Epoch', fontsize=12, labelpad=10)
plt.ylabel('IoU', fontsize=12, labelpad=10)
plt.title('Train IoU (batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()

# %% [markdown]
# ### pixel_acc 그래프

# %%
import matplotlib.pyplot as plt

# x축 데이터 추출
epochs = new['epoch']
pixel_acc = new['pixel_acc']

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# 선 그래프 그리기
plt.plot(epochs, pixel_acc, 
         color='blue', linestyle='-', linewidth=2, label='pixel_acc')

# 축 레이블과 제목 설정
plt.xlabel('Epoch', fontsize=12, labelpad=10)
plt.ylabel('Pixel Accuracy', fontsize=12, labelpad=10)
plt.title('Train Pixel Accuracy (batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()

# %% [markdown]
# ### 검증 데이터

# %%
val=new_data[(new_data['phase']=="val") & (new_data['epoch']<=12)]
val=val[['epoch','epoch_loss','epoch_iou','pixel_acc']]
val
# Out:
#     epoch  epoch_loss  epoch_iou  pixel_acc
# 1       1    0.621031   0.363839   0.717052
# 3       2    0.473274   0.411076   0.735570
# 5       3    0.405747   0.434118   0.744520
# 7       4    0.380510   0.452125   0.747534
# 9       5    0.358771   0.463900   0.751125
# 11      6    0.347350   0.477263   0.752568
# 13      7    0.341594   0.480995   0.753970
# 15      8    0.348553   0.487367   0.753377
# 17      9    0.355233   0.489988   0.752365
# 19     10    0.357355   0.493629   0.753915
# 21     11    0.365191   0.497589   0.754736
# 23     12    0.375609   0.501575   0.753872

# %% [markdown]
# ### loss 그래프

# %%
import matplotlib.pyplot as plt

# x축 데이터 추출
epochs = val['epoch']
epoch_loss = val['epoch_loss']

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# 선 그래프 그리기
plt.plot(epochs, epoch_loss, 
         color='red', linestyle='-', linewidth=2, label='Loss')

# 축 레이블과 제목 설정
plt.xlabel('Epoch', fontsize=12, labelpad=10)
plt.ylabel('Loss', fontsize=12, labelpad=10)
plt.title('Validation Loss (batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()

# %% [markdown]
# ### iou 그래프

# %%
import matplotlib.pyplot as plt

# x축 데이터 추출
epochs = val['epoch']
epoch_iou = val['epoch_iou']

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# 선 그래프 그리기
plt.plot(epochs, epoch_iou, 
         color='red', linestyle='-', linewidth=2, label='IoU')

# 축 레이블과 제목 설정
plt.xlabel('Epoch', fontsize=12, labelpad=10)
plt.ylabel('IoU', fontsize=12, labelpad=10)
plt.title('Validation IoU (batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()

# %% [markdown]
# ### pixel_acc

# %%
import matplotlib.pyplot as plt

# x축 데이터 추출
epochs = val['epoch']
pixel_acc = val['pixel_acc']

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# 선 그래프 그리기
plt.plot(epochs, pixel_acc, 
         color='red', linestyle='-', linewidth=2, label='pixel_acc')

# 축 레이블과 제목 설정
plt.xlabel('Epoch', fontsize=12, labelpad=10)
plt.ylabel('Pixel Accuracy', fontsize=12, labelpad=10)
plt.title('Validation Pixel Accuracy (batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()

# %%
val2=new_data[(new_data['phase']=="val") & (new_data['epoch']<=12)]
val2
# Out:
#     epoch phase  epoch_loss  epoch_iou  pixel_acc  iou_Sidewalk  \
# 1       1   val    0.621031   0.363839   0.717052      0.712704
# 3       2   val    0.473274   0.411076   0.735570      0.725297
# 5       3   val    0.405747   0.434118   0.744520      0.730534
# 7       4   val    0.380510   0.452125   0.747534      0.733302
# 9       5   val    0.358771   0.463900   0.751125      0.731805
# 11      6   val    0.347350   0.477263   0.752568      0.729563
# 13      7   val    0.341594   0.480995   0.753970      0.730471
# 15      8   val    0.348553   0.487367   0.753377      0.720003
# 17      9   val    0.355233   0.489988   0.752365      0.716383
# 19     10   val    0.357355   0.493629   0.753915      0.723760
# 21     11   val    0.365191   0.497589   0.754736      0.724096
# 23     12   val    0.375609   0.501575   0.753872      0.717382
#
#     iou_Braille Guide Blocks  iou_Roadway  iou_Alley  iou_Bike Lane  \
# 1                   0.139200     0.202369   0.734883       0.134009
# 3                   0.172983     0.255888   0.749649       0.170814
# 5                   0.225731     0.269978   0.753429       0.185316
# 7                   0.273695     0.276847   0.753733       0.187451
# 9                   0.308361     0.289173   0.761466       0.190133
# 11                  0.369312     0.287622   0.757155       0.202040
# 13                  0.385356     0.280790   0.761100       0.207186
# 15                  0.413534     0.292377   0.764637       0.218689
# 17                  0.430129     0.300802   0.761332       0.218636
# 19                  0.462871     0.287311   0.761054       0.226971
# 21                  0.482911     0.277428   0.761804       0.224240
# 23                  0.494814     0.288873   0.764870       0.225059
#
#     iou_Caution Zone  iou_Cross walk
# 1           0.475450        0.148259
# 3           0.541604        0.261298
# 5           0.560951        0.312887
# 7           0.590145        0.349703
# 9           0.599720        0.366644
# 11          0.607803        0.387345
# 13          0.599598        0.402463
# 15          0.608803        0.393526
# 17          0.606578        0.396056
# 19          0.604053        0.389382
# 21          0.605548        0.407096
# 23          0.611609        0.408422

# %%
import matplotlib.pyplot as plt

# epoch, IoU 데이터 추출
epochs = val2['epoch']
iou_sidewalk = val2['iou_Sidewalk']
iou_braille = val2['iou_Braille Guide Blocks']
iou_crosswalk = val2['iou_Cross walk']

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(epochs, iou_sidewalk, label='IoU Sidewalk', marker='o')
plt.plot(epochs, iou_braille, label='IoU Braille Guide Blocks', marker='s')
plt.plot(epochs, iou_crosswalk, label='IoU Crosswalk', marker='x')

# 그래프 스타일 설정
plt.title('Safe class IoU(batch_size=64)')
plt.xlabel('Epoch')
plt.ylabel('IoU')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# epoch, IoU 데이터 추출
epochs = val2['epoch']
iou_roadway = val2['iou_Roadway']
iou_alley = val2['iou_Alley']
iou_bike_lane=val2['iou_Bike Lane']
iou_caution_zone=val2['iou_Caution Zone']

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(epochs, iou_roadway, label='IoU Roadway', marker='o')
plt.plot(epochs, iou_alley, label='IoU Alley', marker='s')
plt.plot(epochs, iou_bike_lane, label='IoU Bike lane', marker='x')
plt.plot(epochs, iou_caution_zone, label='IoU Caution Zone', marker='*')

# 그래프 스타일 설정
plt.title('Dangerous class IoU(batch_size=64)')
plt.xlabel('Epoch')
plt.ylabel('IoU')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Epoch Train/val Loss Mix

# %%
import matplotlib.pyplot as plt

# 첫 번째 데이터 (train)
epochs_train = new['epoch']
loss_train = new['epoch_loss']

# 두 번째 데이터 (validation)
epochs_val = val['epoch']
loss_val = val['epoch_loss']

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# Train 데이터 선 그래프
plt.plot(epochs_train, loss_train, 
         color='blue', linestyle='-', linewidth=2, label='Train Loss')

# Validation 데이터 선 그래프
plt.plot(epochs_val, loss_val, 
         color='red', linestyle='-', linewidth=2, label='Validation Loss')

# 축 레이블과 제목 설정
plt.xlabel('Epoch', fontsize=12, labelpad=10)
plt.ylabel('Loss', fontsize=12, labelpad=10)
plt.title('Train / Validation Loss (batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()

# %%
import matplotlib.pyplot as plt

# 첫 번째 데이터 (train)
epochs_train = new['epoch']
iou_train = new['epoch_iou']

# 두 번째 데이터 (validation)
epochs_val = val['epoch']
iou_val = val['epoch_iou']

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# Train IoU 선 그래프
plt.plot(epochs_train, iou_train, 
         color='blue', linestyle='-', linewidth=2, label='Train IoU')

# Validation IoU 선 그래프
plt.plot(epochs_val, iou_val, 
         color='red', linestyle='-', linewidth=2, label='Validation IoU')

# 축 레이블과 제목 설정
plt.xlabel('Epoch', fontsize=12, labelpad=10)
plt.ylabel('IoU', fontsize=12, labelpad=10)
plt.title('Train / Validation IoU (batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()

# %%
import matplotlib.pyplot as plt

# 첫 번째 데이터 (train)
epochs_train = new['epoch']
pixel_acc_train = new['pixel_acc']

# 두 번째 데이터 (validation)
epochs_val = val['epoch']
pixel_acc_val = val['pixel_acc']

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# Train Pixel Accuracy 선 그래프
plt.plot(epochs_train, pixel_acc_train, 
         color='blue', linestyle='-', linewidth=2, label='Train Pixel Accuracy')

# Validation Pixel Accuracy 선 그래프
plt.plot(epochs_val, pixel_acc_val, 
         color='red', linestyle='-', linewidth=2, label='Validation Pixel Accuracy')

# 축 레이블과 제목 설정
plt.xlabel('Epoch', fontsize=12, labelpad=10)
plt.ylabel('Pixel Accuracy', fontsize=12, labelpad=10)
plt.title('Train / Validation Pixel Accuracy (batch_size=64)', fontsize=14, pad=15)

# 격자 추가
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# 범례 추가
plt.legend(fontsize=10, loc='best')

# 그래프 출력
plt.show()
